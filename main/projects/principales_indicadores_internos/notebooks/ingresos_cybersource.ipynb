# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import seaborn as sns
import json

# %%
plt.style.use('seaborn-v0_8-pastel')

# %%
with open('../config/cybersource_conection.json', 'r') as file:
    credenciales = json.load(file)

# %%
connection_string = f"mssql+pyodbc://{credenciales['USERNAME']}:{credenciales['PASSWORD']}@{credenciales['SERVER']}/{credenciales['DATABASE']}?driver=ODBC+Driver+17+for+SQL+Server&timeout=30"
engine = create_engine(connection_string)

# %%
query = """
            SELECT
                BatchDate,
                BillTo_Email,
                BillTo_FirstName,
                BillTo_LastName,
                Status,
                Amount,
                Type,
                TypeDescription,
                AccountSuffix,
                MerchantReferenceNumber
            FROM dbo.Cybersource
            WHERE 
                BatchDate BETWEEN '2022-01-01 00:00:00' AND '2025-12-31 23:59:59'
                AND MerchantReferenceNumber NOT LIKE 'cybs_test%';
            """

df_ingresos = pd.read_sql(query, engine)
df_ingresos.head()
# Out:
#               BatchDate         BillTo_Email BillTo_FirstName BillTo_LastName  \
# 0  2022-07-23T05:10:22Z    ndurette@lyft.com          NIKOLAS         DURETTE
# 1  2022-07-25T05:10:13Z    ndurette@lyft.com          NIKOLAS         DURETTE
# 2  2022-07-26T05:10:24Z    ndurette@lyft.com          NIKOLAS         DURETTE
# 3  2022-07-28T05:10:19Z     mcanale@lyft.com           MEGHAN          CANALE
# 4  2022-07-28T05:10:19Z  trodrigues@lyft.com             TONY       RODRIGUES
#
#     Status  Amount         Type TypeDescription AccountSuffix  \
# 0  BATCHED  136.88  credit card      MasterCard          1021
# 1  BATCHED -136.88  credit card      MasterCard          1021
# 2  BATCHED  136.88  credit card      MasterCard          1021
# 3  BATCHED  391.00  credit card      MasterCard          6229
# 4  BATCHED  234.00  credit card            Visa          1935
#
#   MerchantReferenceNumber
# 0       cyb_cnp0000000019
# 1       cyb_cnp0000000026
# 2       cyb_cnp0000000031
# 3       cyb_cnp0000000047
# 4       cyb_cnp0000000048

# %%
df_ingresos['BatchDate'] = pd.to_datetime(df_ingresos['BatchDate'], format='ISO8601', errors='coerce', utc=True)
df_ingresos.head()
# Out:
#                   BatchDate         BillTo_Email BillTo_FirstName  \
# 0 2022-07-23 05:10:22+00:00    ndurette@lyft.com          NIKOLAS
# 1 2022-07-25 05:10:13+00:00    ndurette@lyft.com          NIKOLAS
# 2 2022-07-26 05:10:24+00:00    ndurette@lyft.com          NIKOLAS
# 3 2022-07-28 05:10:19+00:00     mcanale@lyft.com           MEGHAN
# 4 2022-07-28 05:10:19+00:00  trodrigues@lyft.com             TONY
#
#   BillTo_LastName   Status  Amount         Type TypeDescription AccountSuffix  \
# 0         DURETTE  BATCHED  136.88  credit card      MasterCard          1021
# 1         DURETTE  BATCHED -136.88  credit card      MasterCard          1021
# 2         DURETTE  BATCHED  136.88  credit card      MasterCard          1021
# 3          CANALE  BATCHED  391.00  credit card      MasterCard          6229
# 4       RODRIGUES  BATCHED  234.00  credit card            Visa          1935
#
#   MerchantReferenceNumber
# 0       cyb_cnp0000000019
# 1       cyb_cnp0000000026
# 2       cyb_cnp0000000031
# 3       cyb_cnp0000000047
# 4       cyb_cnp0000000048

# %%
# Crear columna de mes
df_ingresos['Dia'] = df_ingresos['BatchDate'].dt.day
df_ingresos['Mes'] = df_ingresos['BatchDate'].dt.month
df_ingresos['Año'] = df_ingresos['BatchDate'].dt.year
df_ingresos.head()
# Out:
#                   BatchDate         BillTo_Email BillTo_FirstName  \
# 0 2022-07-23 05:10:22+00:00    ndurette@lyft.com          NIKOLAS
# 1 2022-07-25 05:10:13+00:00    ndurette@lyft.com          NIKOLAS
# 2 2022-07-26 05:10:24+00:00    ndurette@lyft.com          NIKOLAS
# 3 2022-07-28 05:10:19+00:00     mcanale@lyft.com           MEGHAN
# 4 2022-07-28 05:10:19+00:00  trodrigues@lyft.com             TONY
#
#   BillTo_LastName   Status  Amount         Type TypeDescription AccountSuffix  \
# 0         DURETTE  BATCHED  136.88  credit card      MasterCard          1021
# 1         DURETTE  BATCHED -136.88  credit card      MasterCard          1021
# 2         DURETTE  BATCHED  136.88  credit card      MasterCard          1021
# 3          CANALE  BATCHED  391.00  credit card      MasterCard          6229
# 4       RODRIGUES  BATCHED  234.00  credit card            Visa          1935
#
#   MerchantReferenceNumber  Dia  Mes   Año
# 0       cyb_cnp0000000019   23    7  2022
# 1       cyb_cnp0000000026   25    7  2022
# 2       cyb_cnp0000000031   26    7  2022
# 3       cyb_cnp0000000047   28    7  2022
# 4       cyb_cnp0000000048   28    7  2022

# %% [markdown]
# #### Ingresos mensuales por mes

# %%
# Agrupar por mes y graficar momtos mensuales
ingresos_mensuales = df_ingresos.groupby(['Año', 'Mes'])['Amount'].sum().reset_index()
plt.figure(figsize=(16,6))
sns.lineplot(data=ingresos_mensuales, x='Mes', y='Amount', hue='Año', marker='o')
plt.title('Ingresos Mensuales por Año')
plt.xlabel('Mes')
plt.ylabel('Ingresos Totales en $ millones')
plt.xticks(range(1,13))
plt.legend(title='Año')
plt.grid()
plt.show()

ingresos_mensuales
# Out:
#      Año  Mes       Amount
# 0   2022    7      2928.88
# 1   2022    8   2045670.34
# 2   2022    9   3218807.82
# 3   2022   10   4102933.80
# 4   2022   11   5326569.98
# 5   2022   12   4528953.37
# 6   2023    1   6452855.80
# 7   2023    2   6332197.79
# 8   2023    3   7221700.70
# 9   2023    4   6691626.27
# 10  2023    5   7020955.94
# 11  2023    6   6895235.24
# 12  2023    7   6842990.49
# 13  2023    8   6196609.58
# 14  2023    9   7317506.44
# 15  2023   10   9370992.95
# 16  2023   11  11915860.84
# 17  2023   12   8659089.89
# 18  2024    1  11517386.32
# 19  2024    2  12256016.41
# 20  2024    3  13536248.50
# 21  2024    4  11908076.07
# 22  2024    5  11435489.56
# 23  2024    6  10482296.51
# 24  2024    7   9584268.43
# 25  2024    8  10029165.28
# 26  2024    9  10898037.82
# 27  2024   10  10349821.54
# 28  2024   11  13647140.87
# 29  2024   12  11002161.67
# 30  2025    1  13764358.64
# 31  2025    2  13161518.73
# 32  2025    3  14357156.96
# 33  2025    4  11715454.03
# 34  2025    5  10691306.53
# 35  2025    6   9936379.60
# 36  2025    7   9601352.82
# 37  2025    8  10154456.95
# 38  2025    9  10207485.83
# 39  2025   10  11229818.88
# 40  2025   11   1664048.83

# %%
# Agrupar por email y obtener ingreso total por usuario
ingresos_por_usuario = df_ingresos.groupby('BillTo_Email')['Amount'].sum().reset_index()
ingresos_por_usuario = ingresos_por_usuario.sort_values(by='Amount', ascending=False)
ingresos_por_usuario.head(10)
# Out:
#                             BillTo_Email    Amount
# 220971          gama_sussoni@hotmail.com  36019.00
# 481005  ricardo.nieto.bautista@gmail.com  27592.95
# 572233          yessica_vgat@hotmail.com  22198.88
# 237035      guillermotvalencia@gmail.com  22004.69
# 570625            yaridtrejo@hotmail.com  19834.78
# 41389               amedrakkar@gmail.com  18904.55
# 491744       romanalonso0403@outlook.com  18623.73
# 333353                  lacume@gmail.com  18546.00
# 429340             nenodarua@hotmail.com  17867.73
# 100124            carlasal77@hotmail.com  17632.00

# %%
ingresos_por_usuario['Amount'].describe()
# Out:
# count    579303.000000
# mean        627.086228
# std         652.617521
# min        -118.000000
# 25%         130.550000
# 50%         521.000000
# 75%        1042.000000
# max       36019.000000
# Name: Amount, dtype: float64

# %%
# Agrupar por año
ingresos_mensuales_año = df_ingresos.groupby(['Año'])['Amount'].sum().reset_index()
plt.figure(figsize=(16,5))
sns.barplot(data=ingresos_mensuales_año, x='Año', y='Amount', palette='viridis')
plt.title('Ingresos Anuales')
plt.xlabel('Año')
plt.ylabel('Ingresos Totales')
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\victor.briones\AppData\Local\Temp\ipykernel_20160\284687978.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ingresos_mensuales_año, x='Año', y='Amount', palette='viridis')

# %%
# Obtener la lista de años únicos
años_unicos = sorted(ingresos_mensuales['Año'].unique())
n_años = len(años_unicos)

# Calcular disposición de subplots
filas = (n_años + 1) // 2  # Redondeo hacia arriba
columnas = 2 if n_años > 1 else 1

# Crear figura con subplots
fig, axes = plt.subplots(filas, columnas, figsize=(15, 5 * filas))
axes = axes.flatten() if n_años > 1 else [axes]

# Generar gráficas para cada año
for i, año in enumerate(años_unicos):
    if i < len(axes):  # Verificar que tenemos suficientes ejes
        ingresos_mensuales_año = ingresos_mensuales[ingresos_mensuales['Año'] == año]
        
        sns.barplot(data=ingresos_mensuales_año, x='Mes', y='Amount', 
                   palette='magma', ax=axes[i])
        axes[i].set_title(f'Ingresos Mensuales en {año}')
        axes[i].set_xlabel('Mes')
        axes[i].set_ylabel('Ingresos Totales en $ millones')
        axes[i].grid(axis='y')

# Ocultar ejes vacíos si los hay
for j in range(len(años_unicos), len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\victor.briones\AppData\Local\Temp\ipykernel_20160\2794748695.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ingresos_mensuales_año, x='Mes', y='Amount',
# C:\Users\victor.briones\AppData\Local\Temp\ipykernel_20160\2794748695.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ingresos_mensuales_año, x='Mes', y='Amount',
# C:\Users\victor.briones\AppData\Local\Temp\ipykernel_20160\2794748695.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ingresos_mensuales_año, x='Mes', y='Amount',
# C:\Users\victor.briones\AppData\Local\Temp\ipykernel_20160\2794748695.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ingresos_mensuales_año, x='Mes', y='Amount',

# %%
import json

# Obtener la lista de años únicos
años_unicos = sorted(ingresos_mensuales['Año'].unique())

# Crear estructura de datos
resultados = {
    "resumen_general": {
        "total_años": len(años_unicos),
        "años_analizados": [int(año) for año in años_unicos],  # Corregido aquí
        "total_general": float(ingresos_mensuales['Amount'].sum())
    },
    "datos_por_año": {}
}

# Agregar datos por año
for año in años_unicos:
    datos_año = ingresos_mensuales[ingresos_mensuales['Año'] == año]
    total_anual = datos_año['Amount'].sum()
    
    resultados["datos_por_año"][str(año)] = {
        "total_anual": float(total_anual),
        "promedio_mensual": float(total_anual / 12),
        "meses": []
    }
    
    for _, fila in datos_año.iterrows():
        resultados["datos_por_año"][str(año)]["meses"].append({
            "mes": fila['Mes'],
            "ingresos": float(fila['Amount'])
        })

# Imprimir JSON formateado
print(json.dumps(resultados, indent=2, ensure_ascii=False))
# Out:
# {
#   "resumen_general": {
#     "total_años": 4,
#     "años_analizados": [
#       2022,
#       2023,
#       2024,
#       2025
#     ],
#     "total_general": 363272932.9
#   },
#   "datos_por_año": {
#     "2022": {
#       "total_anual": 19225864.19,
#       "promedio_mensual": 1602155.3491666669,
#       "meses": [
#         {
#           "mes": 7.0,
#           "ingresos": 2928.88
#         },
#         {
#           "mes": 8.0,
#           "ingresos": 2045670.34
#         },
#         {
#           "mes": 9.0,
#           "ingresos": 3218807.82
#         },
#         {
#           "mes": 10.0,
#           "ingresos": 4102933.8
#         },
#         {
#           "mes": 11.0,
#           "ingresos": 5326569.98
#         },
#         {
#           "mes": 12.0,
#           "ingresos": 4528953.37
#         }
#       ]
#     },
#     "2023": {
#       "total_anual": 90917621.93,
#       "promedio_mensual": 7576468.494166668,
#       "meses": [
#         {
#           "mes": 1.0,
#           "ingresos": 6452855.8
#         },
#         {
#           "mes": 2.0,
#           "ingresos": 6332197.79
#         },
#         {
#           "mes": 3.0,
#           "ingresos": 7221700.7
#         },
#         {
#           "mes": 4.0,
#           "ingresos": 6691626.27
#         },
#         {
#           "mes": 5.0,
#           "ingresos": 7020955.94
#         },
#         {
#           "mes": 6.0,
#           "ingresos": 6895235.24
#         },
#         {
#           "mes": 7.0,
#           "ingresos": 6842990.49
#         },
#         {
#           "mes": 8.0,
#           "ingresos": 6196609.58
#         },
#         {
#           "mes": 9.0,
#           "ingresos": 7317506.44
#         },
#         {
#           "mes": 10.0,
#           "ingresos": 9370992.95
#         },
#         {
#           "mes": 11.0,
#           "ingresos": 11915860.84
#         },
#         {
#           "mes": 12.0,
#           "ingresos": 8659089.89
#         }
#       ]
#     },
#     "2024": {
#       "total_anual": 136646108.98,
#       "promedio_mensual": 11387175.748333333,
#       "meses": [
#         {
#           "mes": 1.0,
#           "ingresos": 11517386.32
#         },
#         {
#           "mes": 2.0,
#           "ingresos": 12256016.41
#         },
#         {
#           "mes": 3.0,
#           "ingresos": 13536248.5
#         },
#         {
#           "mes": 4.0,
#           "ingresos": 11908076.07
#         },
#         {
#           "mes": 5.0,
#           "ingresos": 11435489.56
#         },
#         {
#           "mes": 6.0,
#           "ingresos": 10482296.51
#         },
#         {
#           "mes": 7.0,
#           "ingresos": 9584268.43
#         },
#         {
#           "mes": 8.0,
#           "ingresos": 10029165.28
#         },
#         {
#           "mes": 9.0,
#           "ingresos": 10898037.82
#         },
#         {
#           "mes": 10.0,
#           "ingresos": 10349821.54
#         },
#         {
#           "mes": 11.0,
#           "ingresos": 13647140.87
#         },
#         {
#           "mes": 12.0,
#           "ingresos": 11002161.67
#         }
#       ]
#     },
#     "2025": {
#       "total_anual": 116483337.79999998,
#       "promedio_mensual": 9706944.816666665,
#       "meses": [
#         {
#           "mes": 1.0,
#           "ingresos": 13764358.64
#         },
#         {
#           "mes": 2.0,
#           "ingresos": 13161518.73
#         },
#         {
#           "mes": 3.0,
#           "ingresos": 14357156.96
#         },
#         {
#           "mes": 4.0,
#           "ingresos": 11715454.03
#         },
#         {
#           "mes": 5.0,
#           "ingresos": 10691306.53
#         },
#         {
#           "mes": 6.0,
#           "ingresos": 9936379.6
#         },
#         {
#           "mes": 7.0,
#           "ingresos": 9601352.82
#         },
#         {
#           "mes": 8.0,
#           "ingresos": 10154456.95
#         },
#         {
#           "mes": 9.0,
#           "ingresos": 10207485.83
#         },
#         {
#           "mes": 10.0,
#           "ingresos": 11229818.88
#         },
#         {
#           "mes": 11.0,
#           "ingresos": 1664048.83
#         }
#       ]
#     }
#   }
# }
