# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import seaborn as sns

# %%
plt.style.use('seaborn-v0_8-pastel')

# %%
SERVER = "10.177.73.36"      # IP o nombre del servidor
DATABASE = "ecobici"  # Nombre de la base de datos  
USERNAME = "ecobici"     # Tu usuario
PASSWORD = "Ec0b1c1"  # Tu contraseña
connection_string = f"mssql+pyodbc://{USERNAME}:{PASSWORD}@{SERVER}/{DATABASE}?driver=ODBC+Driver+17+for+SQL+Server&timeout=30"
engine = create_engine(connection_string)

# %%
query = """
            SELECT
                BatchDate,
                BillTo_Email,
                BillTo_FirstName,
                BillTo_LastName,
                Status,
                Amount,
                Type,
                TypeDescription,
                AccountSuffix
            FROM dbo.Cybersource
            WHERE 
                BatchDate BETWEEN '2025-01-01 00:00:00' AND '2025-10-31 23:59:59';
            """

df_ingresos = pd.read_sql(query, engine)
df_ingresos
# Out:
#                    BatchDate               BillTo_Email BillTo_FirstName  \
# 0       2025-01-01T00:33:17Z  vizalvador85d@hotmail.com         SALVADOR
# 1       2025-01-01T00:33:17Z        maoyou167@gmail.com               NA
# 2       2025-01-01T00:33:18Z   ivanmendoza276@yahoo.com             IVAN
# 3       2025-01-01T00:33:17Z      rikkilethal@gmail.com            RIKKI
# 4       2025-01-01T00:33:17Z        ylomeli92@gmail.com           YOVANI
# ...                      ...                        ...              ...
# 413981  2025-10-28T07:31:47Z   alescalona1930@gmail.com        ANA LAURA
# 413982  2025-10-28T07:31:47Z    alheli.way2@hotmail.com           ALHELÍ
# 413983  2025-10-28T07:31:47Z  manulizcano96@hotmail.com           MANUEL
# 413984  2025-10-28T07:31:47Z      juanpriegot@gmail.com             JUAN
# 413985  2025-10-28T07:31:47Z       mabsoldier@gmail.com           AMELIA
#
#          BillTo_LastName   Status  Amount         Type TypeDescription  \
# ...
